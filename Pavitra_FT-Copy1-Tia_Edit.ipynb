# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from mpl_toolkits.mplot3d import Axes3D  # needed for 3D

# %%
def p_field(p_spec):
    return np.array(p_spec["phi"], dtype=float)

def odes_star(tau, y, Gamma, Lambda, wind):
    x, y_, z, vx, vy, vz = y
    v = np.array([vx, vy, vz])
    u = wind

    vrel = v - u
    speed = np.linalg.norm(vrel)

    dxdt = vx
    dydt = vy
    dzdt = vz

    dvxdt = -Lambda * speed * vrel[0]
    dvydt = -Lambda * speed * vrel[1]
    dvzdt = -Gamma - Lambda * speed * vrel[2]

    return [dxdt, dydt, dzdt, dvxdt, dvydt, dvzdt]

# %%
def hit_ground(tau, y):
    return y[2]

hit_ground.terminal = True
hit_ground.direction = -1

# %%
def initial_velocity(theta, phi):
    return np.array([
        np.cos(theta)*np.cos(phi),
        np.cos(theta)*np.sin(phi),
        np.sin(theta)
    ])

# %%
def simulate(theta, phi, Gamma, Lambda, wind,
             z0_star=0.0, tau_max=30.0):

    y0 = np.zeros(6)
    y0[0:3] = [0.0, 0.0, z0_star]
    y0[3:6] = initial_velocity(theta, p_field(phi))

    sol = solve_ivp(
        lambda t, y: odes_star(t, y, Gamma, Lambda, wind),
        (0, tau_max),
        y0,
        events=hit_ground,
        rtol=1e-4,
        atol=1e-6,
        max_step=0.05
    )

    if sol.status != 1:
        return None, None

    xL, yL = sol.y[0, -1], sol.y[1, -1]
    rL = np.hypot(xL, yL)
    psiL = np.arctan2(yL, xL)

    return sol, {"xL": xL, "yL": yL, "rL": rL, "psiL": psiL}

# %%
Gamma  = 0.12    # gravity strength
Lambda = 0.15    # drag strength (increased → less overshoot)
z0_star = 0.0

# %%
winds = [
    {"u_star": (0.0, 0.0, 0.0)},
    {"u_star": (0.05, 0.0, 0.0)},
    {"u_star": (0.10, 0.0, 0.0)},
    {"u_star": (0.15, 0.0, 0.0)},
]

# %%
theta = np.deg2rad(75)   # launch angle
phi   = 0.0              # launch direction

# %%
Gamma  = 0.40      # stronger gravity relative to launch speed
Lambda = 0.40      # strong drag

theta = np.deg2rad(75)
phi   = [
    {"phi": 0.0},
    {"phi": 2*np.pi/5},
    {"phi": 4*np.pi/5},
    {"phi": 6*np.pi/5},
    {"phi": 8*np.pi/5},
]  # different launch directions based on different spoke positions

winds = (0.04, 0.0, 0.0) # keeping wind fixed; in x direction

# %%
plt.figure()
for p in phi:
    sol, _ = simulate(theta, p, Gamma, Lambda, winds)
    if sol is not None:
        plt.plot(sol.y[0], sol.y[2],
                 label=f"phi={p['phi']:.2f} rad")

plt.xlabel(r"$x^*$")
plt.ylabel(r"$z^*$")
plt.title("Jet trajectories under increasing wind")
plt.legend()
plt.show()

# %%
plt.figure()
for p in phi:
    sol, _ = simulate(theta, p, Gamma, Lambda, winds)
    if sol is not None:
        plt.plot(sol.y[1], sol.y[2],
                 label=f"phi={p['phi']:.2f} rad")

plt.xlabel(r"$x^*$")
plt.ylabel(r"$z^*$")
plt.title("Jet trajectories under increasing wind")
plt.legend()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

for p in phi:
    sol, _ = simulate(theta, p, Gamma, Lambda, winds)
    if sol is not None:
        ax.plot(
            sol.y[0],  # x*
            sol.y[1],  # y*
            sol.y[2],  # z*
            label=f"phi={p['phi']:.2f} rad"
        )

ax.set_xlabel(r"$x^*$")
ax.set_ylabel(r"$y^*$")
ax.set_zlabel(r"$z^*$")
ax.set_title("3D fountain jet trajectories")
ax.legend()

plt.show()

# %%
xs, ys = [], []

for p in phi:
    _, land = simulate(theta, p, Gamma, Lambda, winds)
    if land:
        xs.append(land["xL"])
        ys.append(land["yL"])

theta_circ = np.linspace(0, 2*np.pi, 400)
plt.figure()
plt.plot(np.cos(theta_circ), np.sin(theta_circ), label="Basin boundary")
plt.scatter(xs, ys, label="Landing points")
plt.gca().set_aspect("equal")
plt.xlabel(r"$x^*$")
plt.ylabel(r"$y^*$")
plt.title("Landing locations under wind disturbances")
plt.legend()
plt.show()

# %%
angles = np.deg2rad(np.linspace(0, 90, 40))
wind_fixed = (0.1, 0.0, 0.0)

rvals = np.full((len(phi), len(angles)), np.nan)

for j, p in enumerate(phi):
    for i, th in enumerate(angles):
        _, land = simulate(th, p, Gamma, Lambda, wind_fixed)
        if land is not None:
            rvals[j, i] = land["rL"]

plt.figure()
for j, p in enumerate(phi):
    if j == 3:
        break
    plt.plot(np.rad2deg(angles), rvals[j], label=f"spoke {j+1} (phi={p['phi']:.2f})")

plt.axhline(1.0, linestyle="--", label="Basin boundary")
plt.xlabel(r"Launch angle $\theta$ (deg)")
plt.ylabel(r"Landing radius $r_L^*$")
plt.title("Landing radius vs launch angle (one curve per spoke)")
plt.legend()
plt.show()

# %%
plt.figure()
for j, p in enumerate(phi):
    if j < 3:
        continue
    plt.plot(np.rad2deg(angles), rvals[j], label=f"spoke {j+1} (phi={p['phi']:.2f}) rads")

plt.axhline(1.0, linestyle="--", label="Basin boundary")
plt.xlabel(r"Launch angle $\theta$ (deg)")
plt.ylabel(r"Landing radius $r_L^*$")
plt.title("Landing radius vs launch angle (one curve per spoke)")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(np.cos(theta_circ), np.sin(theta_circ), label="Basin")

for j, p in enumerate(phi):
    _, land = simulate(theta, p, Gamma, Lambda, wind_fixed)
    if land:
        plt.plot([0, land["xL"]], [0, land["yL"]], marker="o", label=f"spoke {j+1} (phi={p['phi']:.2f}) rads")

plt.gca().set_aspect("equal")
plt.xlabel(r"$x^*$")
plt.ylabel(r"$y^*$")
plt.title("Five-spoke symmetry of nozzle configuration")
plt.legend(loc="upper left",
    bbox_to_anchor=(1.02, 1.0),
    borderaxespad=0.0)
plt.show()

# %%
Lambdas = np.linspace(0.0, 100, 40)
rvals = []

wind_fixed = {"u_star": (0.05, 0.0, 0.0)}

for Lam in Lambdas:
    _, land = simulate(theta, phi, Gamma, Lam, wind_fixed)
    rvals.append(np.nan if land is None else land["rL"])

plt.plot(Lambdas, rvals)
plt.axhline(1.0, linestyle="--")
plt.xlabel(r"Drag strength $\Lambda$")
plt.ylabel(r"Landing radius $r_L^*$")
plt.title("Effect of drag on basin confinement")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[409], line 7
#       4 wind_fixed = {"u_star": (0.05, 0.0, 0.0)}
#       6 for Lam in Lambdas:
# ----> 7     _, land = simulate(theta, phi, Gamma, Lam, wind_fixed)
#       8     rvals.append(np.nan if land is None else land["rL"])
#      10 plt.plot(Lambdas, rvals)
#
# Cell In[397], line 6, in simulate(theta, phi, Gamma, Lambda, wind, z0_star, tau_max)
#       4 y0 = np.zeros(6)
#       5 y0[0:3] = [0.0, 0.0, z0_star]
# ----> 6 y0[3:6] = initial_velocity(theta, p_field(phi))
#       8 sol = solve_ivp(
#       9     lambda t, y: odes_star(t, y, Gamma, Lambda, wind),
#      10     (0, tau_max),
#    (...)
#      15     max_step=0.05
#      16 )
#      18 if sol.status != 1:
#
# Cell In[394], line 2, in p_field(p_spec)
#       1 def p_field(p_spec):
# ----> 2     return np.array(p_spec["phi"], dtype=float)
#
# TypeError: list indices must be integers or slices, not str

# %%
winds = np.linspace(0.0, 0.1, 10)
rmin = []

for U in winds:
    _, land = simulate(theta, phi, Gamma, Lambda,
                       {"u_star": (U,0,0)})
    rmin.append(land["rL"])

plt.plot(winds, rmin)
plt.axhline(1.0, linestyle="--")
plt.xlabel("Wind strength $u^*$")
plt.ylabel("Minimum landing radius $r_L^*$")
plt.title("Lower bound on basin confinement")
plt.show()

# %%
winds = np.linspace(0.0, 0.15, 10)
r_required = []

for U in winds:
    _, land = simulate(theta, phi, Gamma, Lambda,
                       {"u_star": (U, 0, 0)})
    r_required.append(land["rL"])

plt.figure()
plt.plot(winds, r_required, marker="o")
plt.axhline(1.0, linestyle="--", label="Nominal basin radius")
plt.xlabel("Wind strength $u^*$")
plt.ylabel("Required basin radius $r_{min}^*$")
plt.title("Minimum basin radius required for wind-robust operation")
plt.legend()
plt.show()
